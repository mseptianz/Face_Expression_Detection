# %% [markdown]
# ---
#
# Program ini dibuat untuk melakukan uji coba inference dengan menginputkan data baru menggunakan model yang sebelumnya sudah dibuat dan disimpan.
#
# ---

# %% [markdown]
# # Import Libraries

# %%
import numpy as np 
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow.keras.models import load_model

# %% [markdown]
# # Load Model

# %%
model = load_model('best_model.h5')
# Out:
# WARNING:absl:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %% [markdown]
# # Testing New Image

# %%
# Create a function for test a new image
img_height= 224
img_width= 224

def prediction(file):
  img = tf.keras.utils.load_img(file, target_size=(img_height,img_width))
  x = tf.keras.utils.img_to_array(img)/255

  plt.imshow(img)

  x = np.expand_dims(x, axis=0)

  images = np.vstack([x])
  y_pred_proba = model.predict(images)
  y_pred_class = np.argmax(y_pred_proba[0])

  class_name = ['Ahegao', 'Happy', 'Neutral', 'Sad', 'Surprise', 'angry']
  y_pred_class_name = class_name[y_pred_class]

  print('Prediction : {}'.format(y_pred_class_name))

# %% [markdown]
# ## Testing Image 1

# %%
## Download a new image
img_1 = r"C:\Users\asus\Pictures\WhatsApp Image 2024-11-05 at 15.58.26_bc0e39d0.jpg" 
output = prediction(img_1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step
# Prediction : Sad

# %% [markdown]
# ## Testing Image 2

# %%
## Download a new image
img_2 = r"C:\Users\asus\Pictures\WhatsApp Image 2024-11-05 at 19.13.34_2d1f5bbc.jpg"
output = prediction(img_2)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Prediction : Neutral

# %% [markdown]
# ## Testing Image 3

# %%
## Download a new image
img_3 = r"C:\Users\asus\Pictures\WhatsApp Image 2024-11-05 at 18.51.52_215295ec.jpg"
output = prediction(img_3)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 2s 2s/step
# Prediction : Surprise

# %% [markdown]
# # Evaluation

# %% [markdown]
# Model mampu melakukan prediksi dengan baik. Untuk hasil terbaik, disarankan menggunakan foto dengan aspek rasio 1:1 guna menghindari distorsi pada gambar saat proses resizing. Pastikan juga sudut foto diambil dalam posisi menghadap lurus ke kamera agar prediksi lebih akurat.

# %% [markdown]
# Huggingface: [Click Here!](https://huggingface.co/spaces/mseptianz/expression_detection)
